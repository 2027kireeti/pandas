# %%
import pandas as pd
weather_data={
    "day" : ["1/01/2020","2/01/2020","3/01/2020","4/01/2020","5/01/2020","6/01/2020","7/01/2020","8/01/2020"],
    "temperature" : [32,33,34,35,36,37,38,39],
    "windspread" : [1,2,3,4,5,6,7,8],
    "event" : ["rain","sunny","snow","strom","rain","sunny","snow","sunny"]
 }
df=pd.DataFrame(weather_data)
df
# Out:
#          day  temperature  windspread  event
# 0  1/01/2020           32           1   rain
# 1  2/01/2020           33           2  sunny
# 2  3/01/2020           34           3   snow
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
import pandas as pd
weather_data={
    "day" : ["1/01/2020","2/01/2020","3/01/2020","4/01/2020","5/01/2020","6/01/2020","7/01/2020","8/01/2020"],
    "temperature" : [32,33,34,35,36,37,38,39],
    "windspread" : [1,2,3,4,5,6,7,8],
    "event" : ["rain","sunny","snow","strom","rain","sunny","snow","sunny"]
 }
df=pd.DataFrame(weather_data)
df
# Out:
#          day  temperature  windspread  event
# 0  1/01/2020           32           1   rain
# 1  2/01/2020           33           2  sunny
# 2  3/01/2020           34           3   snow
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df.tail()
# Out:
#          day  temperature  windspread  event
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspread', 'event'], dtype='object')

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspread', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/01/2020
# 1    2/01/2020
# 2    3/01/2020
# 3    4/01/2020
# 4    5/01/2020
# 5    6/01/2020
# 6    7/01/2020
# 7    8/01/2020
# Name: day, dtype: object

# %%
df["event"]
# Out:
# 0     rain
# 1    sunny
# 2     snow
# 3    strom
# 4     rain
# 5    sunny
# 6     snow
# 7    sunny
# Name: event, dtype: object

# %%
df.shape
# Out:
# (8, 4)

# %%
type(df["event"])
# Out:
# pandas.core.series.Series

# %%
df[:]
# Out:
#          day  temperature  windspread  event
# 0  1/01/2020           32           1   rain
# 1  2/01/2020           33           2  sunny
# 2  3/01/2020           34           3   snow
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df[2:]
# Out:
#          day  temperature  windspread  event
# 2  3/01/2020           34           3   snow
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df[4:]
# Out:
#          day  temperature  windspread  event
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df[:-2]
# Out:
#          day  temperature  windspread  event
# 0  1/01/2020           32           1   rain
# 1  2/01/2020           33           2  sunny
# 2  3/01/2020           34           3   snow
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny

# %%
df[["event"]]
# Out:
#    event
# 0   rain
# 1  sunny
# 2   snow
# 3  strom
# 4   rain
# 5  sunny
# 6   snow
# 7  sunny

# %%
df.temperature.mean()
# Out:
# 35.5

# %% [markdown]
# df.describe()

# %%
df[df.temperature>=35]
# Out:
#          day  temperature  windspread  event
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.set_index('day',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-85ae8aebc072> in <module>
# ----> 1 df.set_index('day',inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['day'] are in the columns"

# %%
df.loc['1/01/2020']
# Out:
# temperature      32
# windspread        1
# event          rain
# Name: 1/01/2020, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          day  temperature  windspread  event
# 0  1/01/2020           32           1   rain
# 1  2/01/2020           33           2  sunny
# 2  3/01/2020           34           3   snow
# 3  4/01/2020           35           4  strom
# 4  5/01/2020           36           5   rain
# 5  6/01/2020           37           6  sunny
# 6  7/01/2020           38           7   snow
# 7  8/01/2020           39           8  sunny

# %%
df.set_index("event",inplace=True)
df
# Out:
#              day  temperature  windspread
# event
# rain   1/01/2020           32           1
# sunny  2/01/2020           33           2
# snow   3/01/2020           34           3
# strom  4/01/2020           35           4
# rain   5/01/2020           36           5
# sunny  6/01/2020           37           6
# snow   7/01/2020           38           7
# sunny  8/01/2020           39           8

# %%
df
# Out:
#              day  temperature  windspread
# event
# rain   1/01/2020           32           1
# sunny  2/01/2020           33           2
# snow   3/01/2020           34           3
# strom  4/01/2020           35           4
# rain   5/01/2020           36           5
# sunny  6/01/2020           37           6
# snow   7/01/2020           38           7
# sunny  8/01/2020           39           8

# %%
df.reset_index()
# Out:
#    event        day  temperature  windspread
# 0   rain  1/01/2020           32           1
# 1  sunny  2/01/2020           33           2
# 2   snow  3/01/2020           34           3
# 3  strom  4/01/2020           35           4
# 4   rain  5/01/2020           36           5
# 5  sunny  6/01/2020           37           6
# 6   snow  7/01/2020           38           7
# 7  sunny  8/01/2020           39           8

# %%
df.loc["snow"]
# Out:
#              day  temperature  windspread
# event
# snow   3/01/2020           34           3
# snow   7/01/2020           38           7

# %%
import pandas as pd
k=pd.read_csv("C:\\Users\\devar\\Desktop\\kkkk.csv")
k
# Out:
#    roll no class                 name
# 0      420   ece               rajesh
# 1      421   ece        hari chandana
# 2      422   ece  kireeti devarapalem
# 3      423   ece             jyosthna

# %%
k.head()
# Out:
#    roll no class                 name
# 0      420   ece               rajesh
# 1      421   ece        hari chandana
# 2      422   ece  kireeti devarapalem
# 3      423   ece             jyosthna

# %%
k.tail(1)
# Out:
#    roll no class      name
# 3      423   ece  jyosthna

# %%
df=pd.read_excel("C:\\Users\\devar\\Desktop\\Book1.xlsx")
df
# Out:
#    roll no class                 name
# 0      420   ece               rajesh
# 1      421   ece        hari chandana
# 2      422   ece  kireeti devarapalem
# 3      423   ece             jyosthna

# %%
df=pd.DataFrame()

# %%
weather_data=[
    ("1/1/2020",32,6,"rainy"),
    ("2/1/2020",32,6,"rainy"),
    ("3/1/2020",32,6,"rainy")
]
df=pd.DataFrame(weather_data,columns=["day","temperature","winndspeed","event"])
df
# Out:
#         day  temperature  winndspeed  event
# 0  1/1/2020           32           6  rainy
# 1  2/1/2020           32           6  rainy
# 2  3/1/2020           32           6  rainy
